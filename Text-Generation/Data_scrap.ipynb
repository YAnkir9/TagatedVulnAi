# %% [markdown]
# # Web Scraping CVE Details and Updating a CSV File with Python
#
# This notebook provides a structured approach to scrape CVE details, such as CVSS scores, EPSS scores, vulnerability categories, and references, and update them into a CSV file. The code uses multithreading to process multiple CVEs concurrently for efficiency.
#
# ---
#
# ## **1. Import Required Libraries**

# %%
# %%time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# %%
# %%time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Function to get BeautifulSoup object for a given CVE ID
def get_soup(cve_id, retries=3, delay=5):
    
    url = f"https://www.cvedetails.com/cve/{cve_id}/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers, timeout=10)
            if response.status_code == 200:
                return BeautifulSoup(response.content, 'html.parser')
            else:
                print(f"Failed to fetch {cve_id}: Status {response.status_code}")
        except requests.exceptions.RequestException as e:
            print(f"Attempt {attempt + 1} for {cve_id} failed: {e}")
        time.sleep(delay)
    return None

# Function to scrape CVSS-related data
def scrape_cvss_data(soup):
    cvss_dict = {
        'CVSS Score': [],
        'Severity': [],
        'Vector': [],
        'Exploitability Score': [],
        'Impact Score': [],
        'Score Source': []
    }

    rows = soup.find_all('tr')

    for row in rows:
        score_div = row.find('div', class_='cvssbox')
        if score_div:
            score = score_div.text.strip()
            severity_td = row.find_all('td')[1]
            vector_td = row.find_all('td')[2]
            source_td = row.find_all('td')[5]
            exploitability_td = row.find_all('td')[3]
            impact_td = row.find_all('td')[4]

            severity = severity_td.text.strip() if severity_td else None
            vector = vector_td.text.strip() if vector_td else None
            source = source_td.text.strip() if source_td else None
            exploitability = exploitability_td.text.strip() if exploitability_td else None
            impact = impact_td.text.strip() if impact_td else None


            cvss_dict['CVSS Score'].append(score)
            cvss_dict['Severity'].append(severity)
            cvss_dict['Vector'].append(vector)
            cvss_dict['Exploitability Score'].append(exploitability)
            cvss_dict['Impact Score'].append(impact)
            cvss_dict['Score Source'].append(source)

    return cvss_dict

# Function to scrape EPSS score from the page
def scrape_epss_score(soup):
    epss_tag = soup.find('span', class_=['epss-score', 'epssbox', 'score_4'])
    if epss_tag:
        return epss_tag.text.strip()
    return None

def update_vulnerability_category(soup):
    cwe_section = soup.find('h2', id='cvedH2CWEs')
    if cwe_section:
        cwe_list = cwe_section.find_next('ul', class_='list-group')
        if cwe_list:
            cwe_items = cwe_list.find_all('li', class_='list-group-item')
            cwe_details = [item.find('a').text.strip() for item in cwe_items if item.find('a')]
            updated_value = ', '.join(cwe_details)
            return updated_value
    return None

def update_refrence_links(soup):
    reference_section = soup.find('h2', id='cvedH2References')
    if reference_section:
        reference_links = reference_section.find_next('ul', class_='list-group')
        if reference_links:
            reference_link = reference_links.find_all('li', class_='list-group-item')
            reference_details = [item.find('a')['href'] for item in reference_link if item.find('a')]
            # Join the links with a comma and space, making sure the result is a single string
            updated_reference =', '.join(reference_details)
            return updated_reference
    return None

# Function to process each CVE and fetch its details
def process_cve(cve_id):
    print(f"Processing CVE ID: {cve_id}")
    soup = get_soup(cve_id)
    if not soup:
        return None
    cvss_data = scrape_cvss_data(soup)
    epss_score = scrape_epss_score(soup)
    vulnerability_category = update_vulnerability_category(soup)
    reference_links = update_refrence_links(soup)
    result = {
        'CVE_ID': cve_id,
        'EPSS_Score': epss_score,
        'vulnerability_category':vulnerability_category,
        'CVSS_Scores': cvss_data['CVSS Score'],
        'Severities': cvss_data['Severity'],
        'Vectors': cvss_data['Vector'],
        'Exploitability_Scores': cvss_data['Exploitability Score'],
        'Impact_Scores': cvss_data['Impact Score'],
        'Score_Sources': cvss_data['Score Source'],
        'references':reference_links,
    }
    return result

# Function to update the CVE data in the provided CSV file
def update_cve_data(file_path, max_workers=3, update_interval=10):
    data = pd.read_csv(file_path)

    # Identify rows that need updates (where either CVSS_Score or EPSS_Score is missing)
    rows_to_update = data[data[['CVSS_Score', 'EPSS_Score','references']].isnull().any(axis=1)]

    results = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_index = {executor.submit(process_cve, row['CVE_ID']): index for index, row in rows_to_update.iterrows()}
        for future in as_completed(future_to_index):
            index = future_to_index[future]
            try:
                result = future.result()
                if result:
                    results.append(result)
                    print(f"Fetched data for CVE_ID {result['CVE_ID']}: CVSS Scores {result['CVSS_Scores']}, EPSS {result['EPSS_Score']}, Problem Type {result['vulnerability_category']},References {result['references']}")
                
                # Update every `update_interval` successful results
                if len(results) >= update_interval:
                    update_batch(data, results)
                    results.clear()  # Clear results after each batch update
                    data.to_csv(file_path, index=False)
                    print(f"Batch update completed for {update_interval} CVE IDs.")
            except Exception as e:
                print(f"Error processing CVE ID at index {index}: {e}")

    # Final update for any remaining results
    if results:
        update_batch(data, results)
        data.to_csv(file_path, index=False)
        print(f"Final batch update completed for remaining CVE IDs.")

# Function to update DataFrame with scraped results
def update_batch(data, results):
    for result in results:
        index = data[data['CVE_ID'] == result['CVE_ID']].index[0]
        data.at[index, 'CVSS_Score'] = ', '.join(result['CVSS_Scores'])
        data.at[index, 'EPSS_Score'] = result['EPSS_Score']
        data.at[index, 'Severity'] = ', '.join(result['Severities'])
        data.at[index, 'Vector'] = ', '.join(result['Vectors'])
        data.at[index, 'Exploitability Score'] = ', '.join(result['Exploitability_Scores'])
        data.at[index, 'Impact Score'] = ', '.join(result['Impact_Scores'])
        data.at[index, 'Score Source'] = ', '.join(result['Score_Sources'])
        data.at[index, 'Problem Type']= result['vulnerability_category']
        data.at[index, 'references'] = result['references']
# Replace with your CSV file path
file_path = "/home/ankit/Desktop/projects/CFTs/data/filtered_cve_data2.csv"
update_cve_data(file_path, max_workers=3, update_interval=10)
# Out:
# Processing CVE ID: CVE-2009-2429Processing CVE ID: CVE-2009-1958
#
# Processing CVE ID: CVE-2009-1561
# Processing CVE ID: CVE-2009-1934
# Fetched data for CVE_ID CVE-2009-2429: CVSS Scores ['4.6'], EPSS 0.04%, Problem Type CWE-255,References https://exchange.xforce.ibmcloud.com/vulnerabilities/49338, http://archives.neohapsis.com/archives/fulldisclosure/2009-03/0314.html
# Processing CVE ID: CVE-2009-1152
# Fetched data for CVE_ID CVE-2009-1561: CVSS Scores ['6.8'], EPSS 1.11%, Problem Type CWE-352 Cross-Site Request Forgery (CSRF),References http://www.vupen.com/english/advisories/2009/1172, http://packetstormsecurity.org/0904-exploits/linksysadmin-passwd.txt, http://www.falandodeseguranca.com/?p=17, http://www.securityfocus.com/bid/34616, http://archives.neohapsis.com/archives/bugtraq/2009-04/0198.html
# Processing CVE ID: CVE-2009-1474
# Fetched data for CVE_ID CVE-2009-1958: CVSS Scores ['5.0'], EPSS 6.54%, Problem Type CWE-399,References http://lists.opensuse.org/opensuse-security-announce/2009-07/msg00002.html, http://download.strongswan.org/patches/04_swapped_ts_check_patch/strongswan-4.x.x._swapped_ts_check.readme, http://download.strongswan.org/CHANGES4.txt, http://download.strongswan.org/patches/04_swapped_ts_check_patch/strongswan-4.x.x._swapped_ts_check.patch, http://www.securityfocus.com/bid/35178, https://lists.strongswan.org/pipermail/users/2009-May/003457.html, http://www.debian.org/security/2009/dsa-1899
# Processing CVE ID: CVE-2009-1472
# Fetched data for CVE_ID CVE-2009-1152: CVSS Scores ['7.3'], EPSS 4.75%, Problem Type None,References http://helith.net/txt/siemens_gigaset_se461_wimax_router_remote_dos.txt, https://exchange.xforce.ibmcloud.com/vulnerabilities/49365, http://www.securityfocus.com/bid/34220, https://www.exploit-db.com/exploits/8260
# Processing CVE ID: CVE-2009-1559
# Fetched data for CVE_ID CVE-2009-1474: CVSS Scores ['7.6'], EPSS 0.17%, Problem Type CWE-310,References http://www.securityfocus.com/archive/1/503827/100/0/threaded, https://exchange.xforce.ibmcloud.com/vulnerabilities/50850, http://www.securityfocus.com/bid/35108
# Processing CVE ID: CVE-2009-1165
# Fetched data for CVE_ID CVE-2009-1934: CVSS Scores ['4.3'], EPSS 0.34%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References http://www.securityfocus.com/bid/35204, http://support.avaya.com/elmodocs2/security/ASA-2009-211.htm, http://sunsolve.sun.com/search/document.do?assetkey=1-66-259588-1, http://sunsolve.sun.com/search/document.do?assetkey=1-21-116648-23-1, http://www.securitytracker.com/id?1022334, https://exchange.xforce.ibmcloud.com/vulnerabilities/50951, http://www.vupen.com/english/advisories/2009/1500
# Processing CVE ID: CVE-2009-1163Fetched data for CVE_ID CVE-2009-1472: CVSS Scores ['10.0'], EPSS 0.08%, Problem Type CWE-310,References http://www.securityfocus.com/archive/1/503827/100/0/threaded, http://www.securityfocus.com/bid/35108
#
# Processing CVE ID: CVE-2009-1756
# Fetched data for CVE_ID CVE-2009-1165: CVSS Scores ['7.8'], EPSS 0.68%, Problem Type CWE-399,References http://www.cisco.com/en/US/products/products_security_advisory09186a0080adb3d7.shtml, http://www.securityfocus.com/bid/35817, http://www.vupen.com/english/advisories/2009/2021, http://www.securitytracker.com/id?1022605
# Processing CVE ID: CVE-2009-1166
# Fetched data for CVE_ID CVE-2009-1559: CVSS Scores ['7.8'], EPSS 0.88%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References http://www.vupen.com/english/advisories/2009/1173, http://www.securityfocus.com/bid/34713, https://exchange.xforce.ibmcloud.com/vulnerabilities/50231, http://www.gnucitizen.org/blog/hacking-linksys-ip-cameras-pt-3/
# Processing CVE ID: CVE-2009-1064
# Fetched data for CVE_ID CVE-2009-1756: CVSS Scores ['2.1'], EPSS 0.04%, Problem Type CWE-200 Exposure of Sensitive Information to an Unauthorized Actor,References http://www.openwall.com/lists/oss-security/2009/05/18/2, http://www.securityfocus.com/bid/35015, http://bugs.debian.org/cgi-bin/bugreport.cgi?bug=529306, https://exchange.xforce.ibmcloud.com/vulnerabilities/50611, https://www.redhat.com/archives/fedora-package-announce/2010-January/msg00000.html, https://www.redhat.com/archives/fedora-package-announce/2010-January/msg00009.html
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2009-1558Fetched data for CVE_ID CVE-2009-1163: CVSS Scores ['7.8'], EPSS 0.68%, Problem Type CWE-399,References http://www.cisco.com/en/US/products/products_security_advisory09186a0080ad0f8b.shtml, http://www.securitytracker.com/id?1022444, http://www.securityfocus.com/bid/35477, http://www.cisco.com/en/US/products/products_applied_mitigation_bulletin09186a0080ad0fb2.html
#
# Processing CVE ID: CVE-2009-1556Fetched data for CVE_ID CVE-2009-1166: CVSS Scores ['7.8'], EPSS 0.56%, Problem Type None,References http://www.cisco.com/en/US/products/products_security_advisory09186a0080adb3d7.shtml, http://www.vupen.com/english/advisories/2009/2021, http://www.securitytracker.com/id?1022605
#
# Processing CVE ID: CVE-2009-1555Fetched data for CVE_ID CVE-2009-1558: CVSS Scores ['7.8'], EPSS 13.71%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References http://www.vupen.com/english/advisories/2009/1173, http://www.securityfocus.com/bid/34713, https://exchange.xforce.ibmcloud.com/vulnerabilities/50231, http://www.gnucitizen.org/blog/hacking-linksys-ip-cameras-pt-3/
#
# Processing CVE ID: CVE-2009-1798
# Fetched data for CVE_ID CVE-2009-1064: CVSS Scores ['5.8'], EPSS 0.49%, Problem Type CWE-94 Improper Control of Generation of Code ('Code Injection'),References http://www.securityfocus.com/bid/34200, http://www.waraxe.us/advisory-73.html, https://exchange.xforce.ibmcloud.com/vulnerabilities/49353, https://www.exploit-db.com/exploits/8257
# Processing CVE ID: CVE-2009-1560Fetched data for CVE_ID CVE-2009-1556: CVSS Scores ['3.5'], EPSS 0.20%, Problem Type CWE-200 Exposure of Sensitive Information to an Unauthorized Actor,References http://www.vupen.com/english/advisories/2009/1173, http://www.securityfocus.com/bid/34629, http://www.gnucitizen.org/blog/hacking-linksys-ip-cameras-pt-2/
#
# Processing CVE ID: CVE-2009-1728
# Fetched data for CVE_ID CVE-2009-1798: CVSS Scores ['4.3'], EPSS 0.66%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References http://www.kb.cert.org/vuls/id/166739, http://holisticinfosec.org/content/view/111/45/, http://nam-en.apc.com/cgi-bin/nam_en.cfg/php/enduser/std_adp.php?p_faqid=10887
# Processing CVE ID: CVE-2009-1164
# Fetched data for CVE_ID CVE-2009-1555: CVSS Scores ['5.0'], EPSS 0.66%, Problem Type CWE-200 Exposure of Sensitive Information to an Unauthorized Actor,References http://www.vupen.com/english/advisories/2009/1173, http://www.gnucitizen.org/blog/hacking-linksys-ip-cameras-pt-1/, http://www.securityfocus.com/bid/34596
# Processing CVE ID: CVE-2009-1167
# Fetched data for CVE_ID CVE-2009-1560: CVSS Scores ['7.8'], EPSS 0.22%, Problem Type CWE-310,References http://www.vupen.com/english/advisories/2009/1173, https://exchange.xforce.ibmcloud.com/vulnerabilities/50410, http://www.gnucitizen.org/blog/hacking-linksys-ip-cameras-pt-4/
# Processing CVE ID: CVE-2009-1797
# Fetched data for CVE_ID CVE-2009-1164: CVSS Scores ['7.8'], EPSS 0.18%, Problem Type CWE-399,References http://www.cisco.com/en/US/products/products_security_advisory09186a0080adb3d7.shtml, http://www.vupen.com/english/advisories/2009/2021
# Processing CVE ID: CVE-2000-0428
# Fetched data for CVE_ID CVE-2009-1728: CVSS Scores ['6.8'], EPSS 13.74%, Problem Type CWE-119 Improper Restriction of Operations within the Bounds of a Memory Buffer,References http://support.apple.com/kb/HT3757, http://lists.apple.com/archives/security-announce/2009/Aug/msg00001.html, https://exchange.xforce.ibmcloud.com/vulnerabilities/52423, http://www.vupen.com/english/advisories/2009/2172, http://www.us-cert.gov/cas/techalerts/TA09-218A.html, http://www.securityfocus.com/bid/35954, http://www.securitytracker.com/id?1022674
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2000-0043
# Fetched data for CVE_ID CVE-2009-1167: CVSS Scores ['10.0'], EPSS 0.56%, Problem Type None,References http://www.securitytracker.com/id?1022606, http://www.cisco.com/en/US/products/products_security_advisory09186a0080adb3d7.shtml, http://www.vupen.com/english/advisories/2009/2021
# Processing CVE ID: CVE-2000-0764
# Fetched data for CVE_ID CVE-2009-1797: CVSS Scores ['6.8'], EPSS 0.15%, Problem Type CWE-352 Cross-Site Request Forgery (CSRF),References http://www.kb.cert.org/vuls/id/166739, http://holisticinfosec.org/content/view/111/45/, http://nam-en.apc.com/cgi-bin/nam_en.cfg/php/enduser/std_adp.php?p_faqid=10887
# Processing CVE ID: CVE-2000-0379
# Fetched data for CVE_ID CVE-2000-0428: CVSS Scores ['10.0'], EPSS 0.45%, Problem Type None,References http://www.securityfocus.com/bid/1168, http://www.nai.com/nai_labs/asp_set/advisory/39_Trend.asp
# Processing CVE ID: CVE-2000-0568Fetched data for CVE_ID CVE-2000-0043: CVSS Scores ['7.5'], EPSS 4.16%, Problem Type None,References http://www.securityfocus.com/bid/905
#
# Processing CVE ID: CVE-2000-0619Fetched data for CVE_ID CVE-2000-0764: CVSS Scores ['5.0'], EPSS 1.27%, Problem Type None,References http://www.securityfocus.com/bid/1609, http://archives.neohapsis.com/archives/bugtraq/2000-08/0338.html, https://exchange.xforce.ibmcloud.com/vulnerabilities/5154
#
# Processing CVE ID: CVE-2000-0345
# Fetched data for CVE_ID CVE-2000-0379: CVSS Scores ['3.6'], EPSS 0.05%, Problem Type None,References http://www.securityfocus.com/templates/archive.pike?list=1&msg=200005082054.NAA32590@linux.mtndew.com, http://www.securityfocus.com/bid/1177, http://www.netopia.com/equipment/purchase/fmw_update.html
# Processing CVE ID: CVE-2000-0700Fetched data for CVE_ID CVE-2000-0568: CVSS Scores ['5.0'], EPSS 0.33%, Problem Type None,References http://www.securityfocus.com/templates/archive.pike?list=1&msg=4125690E.00524395.00@guardianit.se, http://www.securityfocus.com/bid/1417
#
# Processing CVE ID: CVE-2000-0930
# Fetched data for CVE_ID CVE-2000-0619: CVSS Scores ['5.0'], EPSS 0.75%, Problem Type None,References http://archives.neohapsis.com/archives/vuln-dev/2000-q2/0680.html, http://archives.neohapsis.com/archives/vuln-dev/2000-q2/0921.html, https://exchange.xforce.ibmcloud.com/vulnerabilities/7364, http://www.securityfocus.com/bid/1258
# Processing CVE ID: CVE-2000-0780
# Fetched data for CVE_ID CVE-2000-0345: CVSS Scores ['2.1'], EPSS 0.05%, Problem Type None,References http://www.securityfocus.com/templates/archive.pike?list=1&msg=20000502222246.28423.qmail@securityfocus.com, http://www.securityfocus.com/bid/1161
# Processing CVE ID: CVE-2000-0451Fetched data for CVE_ID CVE-2000-0700: CVSS Scores ['5.0'], EPSS 0.66%, Problem Type None,References http://www.securityfocus.com/bid/1541, http://www.cisco.com/warp/public/707/gsraclbypassdos-pub.shtml
#
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2000-0255
# Fetched data for CVE_ID CVE-2000-0930: CVSS Scores ['5.0'], EPSS 0.96%, Problem Type None,References http://www.securityfocus.com/bid/1738, https://exchange.xforce.ibmcloud.com/vulnerabilities/5326, http://archives.neohapsis.com/archives/bugtraq/2000-10/0039.html, http://archives.neohapsis.com/archives/bugtraq/2000-10/0436.html
# Processing CVE ID: CVE-2000-0238
# Fetched data for CVE_ID CVE-2000-0780: CVSS Scores ['6.4'], EPSS 0.69%, Problem Type None,References http://www.ipswitch.com/Support/IMail/news.html, http://www.securityfocus.com/bid/1617, https://marc.info/?l=bugtraq&m=96767207207553&w=2
# Processing CVE ID: CVE-2000-0417
# Fetched data for CVE_ID CVE-2000-0451: CVSS Scores ['5.0'], EPSS 0.94%, Problem Type None,References http://www.securityfocus.com/bid/1228, http://archives.neohapsis.com/archives/bugtraq/2000-05/0229.html
# Processing CVE ID: CVE-2000-0301Fetched data for CVE_ID CVE-2000-0238: CVSS Scores ['5.0'], EPSS 1.17%, Problem Type None,References http://www.securityfocus.com/templates/archive.pike?list=1&msg=s8d1f3e3.036@kib.co.kodiak.ak.us, http://www.securityfocus.com/bid/1064
#
# Processing CVE ID: CVE-2000-0882Fetched data for CVE_ID CVE-2000-0255: CVSS Scores ['5.0'], EPSS 0.69%, Problem Type None,References http://archives.neohapsis.com/archives/bugtraq/2000-04/0022.html, http://www.securityfocus.com/bid/1091
#
# Processing CVE ID: CVE-2000-0825Fetched data for CVE_ID CVE-2000-0417: CVSS Scores ['5.0'], EPSS 3.18%, Problem Type None,References http://archives.neohapsis.com/archives/bugtraq/2000-05/0075.html, http://archives.neohapsis.com/archives/bugtraq/2000-05/0280.html, http://www.securityfocus.com/bid/1219
#
# Processing CVE ID: CVE-2000-0178
# Fetched data for CVE_ID CVE-2000-0301: CVSS Scores ['5.0'], EPSS 0.48%, Problem Type None,References http://www.securityfocus.com/bid/1094, https://marc.info/?l=bugtraq&m=95505800117143&w=2, http://support.ipswitch.com/kb/IM-20000208-DM02.htm
# Processing CVE ID: CVE-2000-0836
# Fetched data for CVE_ID CVE-2000-0882: CVSS Scores ['5.0'], EPSS 0.28%, Problem Type None,References http://www.securityfocus.com/bid/1647, http://archives.neohapsis.com/archives/bugtraq/2000-08/0533.html
# Processing CVE ID: CVE-2000-0380Fetched data for CVE_ID CVE-2000-0825: CVSS Scores ['5.0'], EPSS 0.70%, Problem Type None,References http://www.securityfocus.com/bid/2011, https://marc.info/?l=bugtraq&m=96659012127444&w=2, http://archives.neohapsis.com/archives/win2ksecadvice/2000-q3/0071.html, https://exchange.xforce.ibmcloud.com/vulnerabilities/5475, https://marc.info/?l=ntbugtraq&m=96654521004571&w=2
#
# Processing CVE ID: CVE-2000-0418
# Fetched data for CVE_ID CVE-2000-0178: CVSS Scores ['7.5'], EPSS 0.72%, Problem Type None,References http://www.securityfocus.com/bid/1017, http://www.foundrynet.com/bugTraq.html
# Processing CVE ID: CVE-2000-0945
# Batch update completed for 10 CVE IDs.
# Fetched data for CVE_ID CVE-2000-0836: CVSS Scores ['7.5'], EPSS 1.99%, Problem Type None,References http://www.securityfocus.com/bid/1685, http://archives.neohapsis.com/archives/bugtraq/2000-09/0176.html, https://exchange.xforce.ibmcloud.com/vulnerabilities/5246
# Processing CVE ID: CVE-2000-1170
# Fetched data for CVE_ID CVE-2000-0380: CVSS Scores ['7.1'], EPSS 95.97%, Problem Type CWE-20 Improper Input Validation,References http://www.securityfocus.com/bid/1154, http://www.cisco.com/warp/public/707/ioshttpserver-pub.shtml, http://archives.neohapsis.com/archives/bugtraq/2000-04/0261.html
# Processing CVE ID: CVE-2000-1179
# Fetched data for CVE_ID CVE-2000-1170: CVSS Scores ['7.5'], EPSS 1.11%, Problem Type None,References https://marc.info/?l=bugtraq&m=97439536016554&w=2, http://www.securityfocus.com/bid/1956, http://www.netsnap.com/new.htm, https://exchange.xforce.ibmcloud.com/vulnerabilities/5534
# Processing CVE ID: CVE-2021-34559
# Fetched data for CVE_ID CVE-2000-0418: CVSS Scores ['5.0'], EPSS 0.33%, Problem Type None,References http://www.securityfocus.com/bid/1240, http://archives.neohapsis.com/archives/bugtraq/2000-05/0280.html
# Processing CVE ID: CVE-2021-34203
# Fetched data for CVE_ID CVE-2000-0945: CVSS Scores ['10.0'], EPSS 96.96%, Problem Type None,References https://exchange.xforce.ibmcloud.com/vulnerabilities/5415, http://www.securityfocus.com/bid/1846, http://archives.neohapsis.com/archives/bugtraq/2000-11/0194.html, http://archives.neohapsis.com/archives/bugtraq/2000-10/0380.html
# Processing CVE ID: CVE-2021-34860Fetched data for CVE_ID CVE-2000-1179: CVSS Scores ['5.0'], EPSS 0.32%, Problem Type None,References https://exchange.xforce.ibmcloud.com/vulnerabilities/5536, http://www.securityfocus.com/bid/1952, https://marc.info/?l=bugtraq&m=97440068130051&w=2
#
# Processing CVE ID: CVE-2021-34734Fetched data for CVE_ID CVE-2021-34559: CVSS Scores ['5.0', '5.4', '5.3'], EPSS 0.12%, Problem Type CWE-444 Inconsistent Interpretation of HTTP Requests ('HTTP Request/Response Smuggling'),References https://cert.vde.com/en-us/advisories/vde-2021-027
# Processing CVE ID: CVE-2021-34346
# Fetched data for CVE_ID CVE-2021-34203: CVSS Scores ['4.8', '8.1'], EPSS 0.16%, Problem Type CWE-1188 Initialization of a Resource with an Insecure Default,References http://dir-2640-us.com, https://www.dlink.com/en/security-bulletin/, https://github.com/liyansong2018/CVE/tree/main/2021/CVE-2021-34203, http://d-link.com
#
# Processing CVE ID: CVE-2021-34776Fetched data for CVE_ID CVE-2021-34860: CVSS Scores ['3.3', '6.5', '6.5'], EPSS 0.34%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://www.zerodayinitiative.com/advisories/ZDI-21-976/, https://supportannouncement.us.dlink.com/announcement/publication.aspx?name=SAP10201
#
# Processing CVE ID: CVE-2021-34696
# Fetched data for CVE_ID CVE-2021-34734: CVSS Scores ['6.1', '6.5', '6.5'], EPSS 0.06%, Problem Type CWE-415 Double Free,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-ipcamera-lldp-dos-OFP7j9j
# Processing CVE ID: CVE-2021-34829
# Batch update completed for 10 CVE IDs.
# Fetched data for CVE_ID CVE-2021-34346: CVSS Scores ['7.5', '9.8', '9.8'], EPSS 0.49%, Problem Type CWE-787 Out-of-bounds Write,References https://www.qnap.com/en/security-advisory/qsa-21-36
# Processing CVE ID: CVE-2021-34982Fetched data for CVE_ID CVE-2021-34776: CVSS Scores ['2.9', '4.3', '4.3'], EPSS 0.07%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb220-lldp-multivuls-mVRUtQ8T
#
# Processing CVE ID: CVE-2021-34977Fetched data for CVE_ID CVE-2021-34829: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.28%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://www.zerodayinitiative.com/advisories/ZDI-21-681/
#
# Processing CVE ID: CVE-2021-34861
# Fetched data for CVE_ID CVE-2021-34696: CVSS Scores ['5.0', '5.8', '5.8'], EPSS 0.13%, Problem Type CWE-284 Improper Access Control,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-asr900acl-UeEyCxkv
# Processing CVE ID: CVE-2021-34564
# Fetched data for CVE_ID CVE-2021-34982: CVSS Scores ['8.8'], EPSS 0.05%, Problem Type CWE-121 Stack-based Buffer Overflow,References https://www.zerodayinitiative.com/advisories/ZDI-21-1274/, https://kb.netgear.com/000064313/Security-Advisory-for-Pre-Authentication-Buffer-Overflow-on-Some-Extenders-Routers-and-DSL-Modem-Routers-PSV-2021-0159
# Processing CVE ID: CVE-2021-34656Fetched data for CVE_ID CVE-2021-34977: CVSS Scores ['5.8', '8.8', '8.8'], EPSS 0.07%, Problem Type CWE-287 Improper Authentication, CWE-288 Authentication Bypass Using an Alternate Path or Channel,References https://kb.netgear.com/000064046/Security-Advisory-for-Authentication-Bypass-on-Some-Routers-and-DSL-Modem-Routers-PSV-2021-0134, https://www.zerodayinitiative.com/advisories/ZDI-21-1239/
#
# Processing CVE ID: CVE-2021-34744
# Fetched data for CVE_ID CVE-2021-34861: CVSS Scores ['5.8', '8.8', '8.8'], EPSS 0.38%, Problem Type CWE-121 Stack-based Buffer Overflow,References https://www.zerodayinitiative.com/advisories/ZDI-21-977/, https://supportannouncement.us.dlink.com/announcement/publication.aspx?name=SAP10201
# Processing CVE ID: CVE-2021-34713Fetched data for CVE_ID CVE-2021-34564: CVSS Scores ['2.1', '5.5', '5.5'], EPSS 0.04%, Problem Type CWE-315 Cleartext Storage of Sensitive Information in a Cookie,References https://cert.vde.com/en-us/advisories/vde-2021-027
#
# Processing CVE ID: CVE-2021-34561
# Fetched data for CVE_ID CVE-2021-34656: CVSS Scores ['4.3', '6.1', '6.1'], EPSS 0.08%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://plugins.trac.wordpress.org/browser/webcam-2way-videochat/trunk/inc/requirements.php#L182, https://www.wordfence.com/vulnerability-advisories/#CVE-2021-34656
# Processing CVE ID: CVE-2021-34730Fetched data for CVE_ID CVE-2021-34744: CVSS Scores ['4.0', '4.9', '4.9'], EPSS 0.07%, Problem Type CWE-540 Inclusion of Sensitive Information in Source Code, CWE-798 Use of Hard-coded Credentials,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb-hardcoded-cred-MJCEXvX
#
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-34236Fetched data for CVE_ID CVE-2021-34713: CVSS Scores ['6.1', '7.4', '7.4'], EPSS 0.06%, Problem Type CWE-399,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-npspin-QYpwdhFD
#
# Processing CVE ID: CVE-2021-34562Fetched data for CVE_ID CVE-2021-34561: CVSS Scores ['6.8', '7.5', '8.8'], EPSS 0.27%, Problem Type CWE-350 Reliance on Reverse DNS Resolution for a Security-Critical Action,References https://cert.vde.com/en-us/advisories/vde-2021-027
#
# Processing CVE ID: CVE-2021-34757Fetched data for CVE_ID CVE-2021-34730: CVSS Scores ['10.0', '9.8', '9.8'], EPSS 0.57%, Problem Type CWE-121 Stack-based Buffer Overflow, CWE-787 Out-of-bounds Write,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-cisco-sb-rv-overflow-htpymMB5
#
# Processing CVE ID: CVE-2021-34828Fetched data for CVE_ID CVE-2021-34236: CVSS Scores ['9.8'], EPSS 0.46%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://github.com/Davidteeri/Bug-Report/blob/main/netgear-8000.md, https://github.com/advisories/GHSA-vfq9-7wg3-4mjx
#
# Processing CVE ID: CVE-2021-34737
# Fetched data for CVE_ID CVE-2021-34562: CVSS Scores ['4.3', '5.4', '6.1'], EPSS 0.06%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://cert.vde.com/en-us/advisories/vde-2021-027
# Processing CVE ID: CVE-2021-34775Fetched data for CVE_ID CVE-2021-34757: CVSS Scores ['3.6', '4.9', '5.5'], EPSS 0.04%, Problem Type CWE-540 Inclusion of Sensitive Information in Source Code, CWE-798 Use of Hard-coded Credentials,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb-hardcoded-cred-MJCEXvX
#
# Processing CVE ID: CVE-2021-34795Fetched data for CVE_ID CVE-2021-34828: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.13%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://www.zerodayinitiative.com/advisories/ZDI-21-680/
#
# Processing CVE ID: CVE-2021-34204
# Fetched data for CVE_ID CVE-2021-34737: CVSS Scores ['5.0', '5.8', '7.5'], EPSS 0.15%, Problem Type CWE-476 NULL Pointer Dereference,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-iosxr-dhcp-dos-pjPVReLU
# Processing CVE ID: CVE-2021-34739
# Fetched data for CVE_ID CVE-2021-34775: CVSS Scores ['2.9', '4.3', '4.3'], EPSS 0.07%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb220-lldp-multivuls-mVRUtQ8T
# Processing CVE ID: CVE-2021-34870Fetched data for CVE_ID CVE-2021-34795: CVSS Scores ['7.5', '10.0', '9.8'], EPSS 0.24%, Problem Type CWE-284 Improper Access Control, CWE-1188 Initialization of a Resource with an Insecure Default,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-catpon-multivulns-CE3DSYGr
#
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-34174
# Fetched data for CVE_ID CVE-2021-34204: CVSS Scores ['7.2', '6.8'], EPSS 0.19%, Problem Type CWE-522 Insufficiently Protected Credentials,References https://github.com/liyansong2018/CVE/tree/main/2021/CVE-2021-34204, http://dir-2640-us.com, https://www.dlink.com/en/security-bulletin/, http://d-link.com
# Processing CVE ID: CVE-2021-34862Fetched data for CVE_ID CVE-2021-34739: CVSS Scores ['6.8', '8.1', '8.1'], EPSS 0.29%, Problem Type CWE-613 Insufficient Session Expiration,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-smb-switches-tokens-UzwpR4e5
#
# Processing CVE ID: CVE-2021-34790Fetched data for CVE_ID CVE-2021-34870: CVSS Scores ['3.3', '6.5', '6.5'], EPSS 0.13%, Problem Type CWE-306 Missing Authentication for Critical Function,References https://kb.netgear.com/000063967/Security-Advisory-for-a-Security-Misconfiguration-Vulnerability-on-the-XR1000-PSV-2021-0101, https://www.zerodayinitiative.com/advisories/ZDI-21-1058/
#
# Processing CVE ID: CVE-2021-34709Fetched data for CVE_ID CVE-2021-34174: CVSS Scores ['4.9', '4.6'], EPSS 0.07%, Problem Type None,References https://github.com/E7mer/OWFuzz, https://github.com/E7mer
#
# Processing CVE ID: CVE-2021-34546
# Fetched data for CVE_ID CVE-2021-34862: CVSS Scores ['5.8', '8.8', '8.8'], EPSS 0.38%, Problem Type CWE-121 Stack-based Buffer Overflow,References https://www.zerodayinitiative.com/advisories/ZDI-21-978/, https://supportannouncement.us.dlink.com/announcement/publication.aspx?name=SAP10201
# Processing CVE ID: CVE-2021-34778Fetched data for CVE_ID CVE-2021-34790: CVSS Scores ['5.0', '4.7', '5.3'], EPSS 0.13%, Problem Type CWE-20 Improper Input Validation, CWE-358 Improperly Implemented Security Check for Standard,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-natalg-bypass-cpKGqkng
#
# Processing CVE ID: CVE-2021-34827Fetched data for CVE_ID CVE-2021-34709: CVSS Scores ['6.9', '6.0', '6.4'], EPSS 0.04%, Problem Type CWE-347 Improper Verification of Cryptographic Signature,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-lnt-QN9mCzwn
#
# Processing CVE ID: CVE-2021-34983
# Fetched data for CVE_ID CVE-2021-34546: CVSS Scores ['7.2', '6.8'], EPSS 0.10%, Problem Type CWE-287 Improper Authentication,References https://www.netsetman.com, http://packetstormsecurity.com/files/163097/NetSetManPro-4.7.2-Privilege-Escalation.html, https://www.secuvera.de, http://seclists.org/fulldisclosure/2021/Jun/17, https://www.secuvera.de/advisories/secuvera-SA-2021-01.txt
# Processing CVE ID: CVE-2021-34791Fetched data for CVE_ID CVE-2021-34778: CVSS Scores ['2.9', '4.3', '4.3'], EPSS 0.07%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb220-lldp-multivuls-mVRUtQ8T
#
# Processing CVE ID: CVE-2021-34979Fetched data for CVE_ID CVE-2021-34827: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.29%, Problem Type CWE-121 Stack-based Buffer Overflow,References https://www.zerodayinitiative.com/advisories/ZDI-21-679/
#
# Processing CVE ID: CVE-2021-34563
# Batch update completed for 10 CVE IDs.
# Fetched data for CVE_ID CVE-2021-34983: CVSS Scores ['6.5'], EPSS 0.05%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'), CWE-306 Missing Authentication for Critical Function,References https://kb.netgear.com/000064313/Security-Advisory-for-Pre-Authentication-Buffer-Overflow-on-Some-Extenders-Routers-and-DSL-Modem-Routers-PSV-2021-0159, https://www.zerodayinitiative.com/advisories/ZDI-21-1275/
# Processing CVE ID: CVE-2021-34978
# Fetched data for CVE_ID CVE-2021-34791: CVSS Scores ['5.0', '4.7', '5.3'], EPSS 0.13%, Problem Type CWE-20 Improper Input Validation, CWE-358 Improperly Implemented Security Check for Standard,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-natalg-bypass-cpKGqkng
# Processing CVE ID: CVE-2021-34708
# Fetched data for CVE_ID CVE-2021-34563: CVSS Scores ['2.1', '3.3', '3.3'], EPSS 0.04%, Problem Type CWE-1004 Sensitive Cookie Without 'HttpOnly' Flag,References https://cert.vde.com/en-us/advisories/vde-2021-027
# Processing CVE ID: CVE-2021-34824
# Fetched data for CVE_ID CVE-2021-34979: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.20%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://www.zerodayinitiative.com/advisories/ZDI-21-1241/, https://kb.netgear.com/000064261/Security-Advisory-for-Vertical-Privilege-Escalation-on-Some-Routers-PSV-2021-0152?article=000064261
# Processing CVE ID: CVE-2021-34980
# Fetched data for CVE_ID CVE-2021-34978: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.16%, Problem Type CWE-121 Stack-based Buffer Overflow, CWE-787 Out-of-bounds Write,References https://kb.netgear.com/000064258/Security-Advisory-for-Vertical-Privilege-Escalation-on-Some-Routers-DSL-Modem-Routers-and-Access-Points-PSV-2021-0151-and-PSV-2021-0170?article=000064258, https://www.zerodayinitiative.com/advisories/ZDI-21-1240/
# Processing CVE ID: CVE-2021-34777
# Fetched data for CVE_ID CVE-2021-34824: CVSS Scores ['6.5', '8.8'], EPSS 0.10%, Problem Type None,References https://istio.io/latest/news/security/istio-security-2021-007, https://github.com/istio/istio/releases
# Processing CVE ID: CVE-2021-34345
# Fetched data for CVE_ID CVE-2021-34708: CVSS Scores ['7.2', '6.0', '6.7'], EPSS 0.04%, Problem Type CWE-347 Improper Verification of Cryptographic Signature,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-lnt-QN9mCzwn
# Processing CVE ID: CVE-2021-34779
# Fetched data for CVE_ID CVE-2021-34980: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.23%, Problem Type CWE-121 Stack-based Buffer Overflow, CWE-787 Out-of-bounds Write,References https://kb.netgear.com/000064262/Security-Advisory-for-Vertical-Privilege-Escalation-on-Some-Routers-PSV-2021-0150?article=000064262, https://www.zerodayinitiative.com/advisories/ZDI-21-1242/
# Processing CVE ID: CVE-2021-34830Fetched data for CVE_ID CVE-2021-34777: CVSS Scores ['2.9', '4.3', '4.3'], EPSS 0.07%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb220-lldp-multivuls-mVRUtQ8T
#
# Processing CVE ID: CVE-2021-34863
# Fetched data for CVE_ID CVE-2021-34345: CVSS Scores ['7.5', '9.8', '9.8'], EPSS 0.49%, Problem Type CWE-787 Out-of-bounds Write,References https://www.qnap.com/en/security-advisory/qsa-21-36
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-34947
# Fetched data for CVE_ID CVE-2021-34779: CVSS Scores ['7.9', '4.3', '8.8'], EPSS 0.09%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb220-lldp-multivuls-mVRUtQ8T
# Processing CVE ID: CVE-2021-34565
# Processing CVE ID: CVE-2021-34865
# Fetched data for CVE_ID CVE-2021-34863: CVSS Scores ['5.8', '8.8', '8.8'], EPSS 0.38%, Problem Type CWE-121 Stack-based Buffer Overflow,References https://supportannouncement.us.dlink.com/announcement/publication.aspx?name=SAP10201, https://www.zerodayinitiative.com/advisories/ZDI-21-979/
# Fetched data for CVE_ID CVE-2021-34830: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.29%, Problem Type CWE-121 Stack-based Buffer Overflow,References https://www.zerodayinitiative.com/advisories/ZDI-21-682/
# Processing CVE ID: CVE-2021-34991
# Fetched data for CVE_ID CVE-2021-34947: CVSS Scores ['8.8'], EPSS 0.05%, Problem Type CWE-787 Out-of-bounds Write,References https://www.zerodayinitiative.com/advisories/ZDI-21-1116/, https://kb.netgear.com/000064044/Security-Advisory-for-Pre-Authentication-Buffer-Overflow-on-Some-Routers-PSV-2021-0129
# Processing CVE ID: CVE-2021-34780Fetched data for CVE_ID CVE-2021-34991: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.15%, Problem Type CWE-121 Stack-based Buffer Overflow, CWE-787 Out-of-bounds Write,References https://kb.netgear.com/000064361/Security-Advisory-for-Pre-Authentication-Buffer-Overflow-on-Multiple-Products-PSV-2021-0168, https://www.zerodayinitiative.com/advisories/ZDI-21-1303/
#
# Processing CVE ID: CVE-2021-34560Fetched data for CVE_ID CVE-2021-34565: CVSS Scores ['7.5', '9.8', '9.8'], EPSS 0.18%, Problem Type CWE-798 Use of Hard-coded Credentials,References https://cert.vde.com/en-us/advisories/vde-2021-027
#
# Processing CVE ID: CVE-2021-39309
# Fetched data for CVE_ID CVE-2021-34865: CVSS Scores ['8.3', '8.8', '8.8'], EPSS 0.44%, Problem Type CWE-287 Improper Authentication, CWE-697 Incorrect Comparison,References https://www.zerodayinitiative.com/advisories/ZDI-21-1051/, https://kb.netgear.com/000063955/Security-Advisory-for-Authentication-Bypass-Vulnerability-on-Some-Routers-PSV-2021-0083?article=000063955
# Processing CVE ID: CVE-2021-39364Fetched data for CVE_ID CVE-2021-34780: CVSS Scores ['7.9', '4.3', '8.8'], EPSS 0.09%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-sb220-lldp-multivuls-mVRUtQ8T
#
# Processing CVE ID: CVE-2021-39677
# Fetched data for CVE_ID CVE-2021-34560: CVSS Scores ['2.1', '5.5', '5.5'], EPSS 0.04%, Problem Type CWE-522 Insufficiently Protected Credentials,References https://cert.vde.com/en-us/advisories/vde-2021-027
# Processing CVE ID: CVE-2021-39308
# Fetched data for CVE_ID CVE-2021-39309: CVSS Scores ['4.3', '6.1'], EPSS 0.09%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://plugins.trac.wordpress.org/browser/parsian-bank-gateway-for-woocommerce/tags/1.0/vendor/dpsoft/parsian-payment/sample/rollback-payment.php#L39, https://www.wordfence.com/vulnerability-advisories/#CVE-2021-39309
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-39086Fetched data for CVE_ID CVE-2021-39364: CVSS Scores ['5.0', '7.5'], EPSS 0.14%, Problem Type CWE-294 Authentication Bypass by Capture-replay,References https://buildings.honeywell.com/content/dam/hbtbt/en/documents/downloads/Security_Notification_SN_2022-01-26-02_CVE-2021-39364_Video_Replay_HBW2PER1.pdf, https://www.honeywell.com/us/en/product-security, https://buildings.honeywell.com/us/en/brands/our-brands/security/support-and-resources/product-resources/eol-and-security-notices
#
# Processing CVE ID: CVE-2021-39474Fetched data for CVE_ID CVE-2021-39677: CVSS Scores ['5.0', '7.5'], EPSS 0.08%, Problem Type CWE-125 Out-of-bounds Read,References https://source.android.com/security/bulletin/aaos/2022-02-01
#
# Processing CVE ID: CVE-2021-39510Fetched data for CVE_ID CVE-2021-39308: CVSS Scores ['4.3', '6.1'], EPSS 0.09%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://www.wordfence.com/vulnerability-advisories/#CVE-2021-39308, https://plugins.trac.wordpress.org/browser/woo-myghpay-payment-gateway/trunk/processresponse.php?rev=2410420#L134
#
# Processing CVE ID: CVE-2021-39772Fetched data for CVE_ID CVE-2021-39474: CVSS Scores ['9.0', '7.2'], EPSS 1.61%, Problem Type CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References https://www.ubeeinteractive.com/?product=ubc1319, https://saikotwolf.medium.com/f9ed24e14e51
#
# Processing CVE ID: CVE-2021-37722
# Fetched data for CVE_ID CVE-2021-39086: CVSS Scores ['4.3', '5.3'], EPSS 0.10%, Problem Type CWE-209 Generation of Error Message Containing Sensitive Information,References https://exchange.xforce.ibmcloud.com/vulnerabilities/215889, https://www.ibm.com/support/pages/node/6612537
# Processing CVE ID: CVE-2021-37719
# Fetched data for CVE_ID CVE-2021-39510: CVSS Scores ['7.5', '9.8'], EPSS 4.71%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://github.com/doudoudedi/main-DIR-816_A1_Command-injection/blob/main/injection_A1.md, https://www.dlink.com/en/security-bulletin/, https://github.com/doudoudedi/main-DIR-816_A1_Command-injection
# Processing CVE ID: CVE-2021-37729Fetched data for CVE_ID CVE-2021-37722: CVSS Scores ['9.0', '7.2'], EPSS 0.67%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
#
# Processing CVE ID: CVE-2021-37720Fetched data for CVE_ID CVE-2021-39772: CVSS Scores ['5.8', '8.8'], EPSS 0.05%, Problem Type CWE-269 Improper Privilege Management,References https://source.android.com/security/bulletin/android-12l
#
# Processing CVE ID: CVE-2021-37740Fetched data for CVE_ID CVE-2021-37719: CVSS Scores ['9.0', '7.2'], EPSS 0.18%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
#
# Processing CVE ID: CVE-2021-37717Fetched data for CVE_ID CVE-2021-37740: CVSS Scores ['7.8', '7.5'], EPSS 0.32%, Problem Type None,References https://www.mdt.de/EN_IP_Interface_Router.html, https://www.mdt.de/download/MDT_CL_SCN_IP_03_IP_Interface_Router.pdf, https://github.com/robertguetzkow/CVE-2021-37740
#
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-37718Fetched data for CVE_ID CVE-2021-37720: CVSS Scores ['9.0', '7.2'], EPSS 0.67%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
#
# Processing CVE ID: CVE-2021-37725
# Fetched data for CVE_ID CVE-2021-37717: CVSS Scores ['9.0', '7.2'], EPSS 0.67%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
# Processing CVE ID: CVE-2021-37273Fetched data for CVE_ID CVE-2021-37718: CVSS Scores ['9.0', '7.2'], EPSS 0.67%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
#
# Processing CVE ID: CVE-2021-37733Fetched data for CVE_ID CVE-2021-37729: CVSS Scores ['5.5', '6.5'], EPSS 0.10%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
#
# Processing CVE ID: CVE-2021-37913
# Fetched data for CVE_ID CVE-2021-37725: CVSS Scores ['8.8', '8.1'], EPSS 0.05%, Problem Type CWE-352 Cross-Site Request Forgery (CSRF),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
# Processing CVE ID: CVE-2021-37716
# Fetched data for CVE_ID CVE-2021-37273: CVSS Scores ['7.8', '7.5'], EPSS 0.09%, Problem Type None,References https://www.cnvd.org.cn/flaw/show/2958526
# Processing CVE ID: CVE-2021-37910
# Fetched data for CVE_ID CVE-2021-37733: CVSS Scores ['4.0', '4.9'], EPSS 0.08%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
# Processing CVE ID: CVE-2021-37624Fetched data for CVE_ID CVE-2021-37913: CVSS Scores ['10.0', '9.8'], EPSS 0.38%, Problem Type CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References https://www.twcert.org.tw/tw/cp-132-5092-f88e2-1.html
#
# Processing CVE ID: CVE-2021-37316
# Fetched data for CVE_ID CVE-2021-37716: CVSS Scores ['10.0', '9.8'], EPSS 0.71%, Problem Type CWE-120 Buffer Copy without Checking Size of Input ('Classic Buffer Overflow'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
# Processing CVE ID: CVE-2021-37317
# Fetched data for CVE_ID CVE-2021-37910: CVSS Scores ['5.0', '5.3', '3.7'], EPSS 0.07%, Problem Type CWE-799 Improper Control of Interaction Frequency,References https://www.twcert.org.tw/tw/cp-132-5259-22a26-1.html
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-37315
# Fetched data for CVE_ID CVE-2021-37624: CVSS Scores ['5.0', '7.5', '7.5'], EPSS 0.24%, Problem Type CWE-287 Improper Authentication, CWE-306 Missing Authentication for Critical Function,References http://www.openwall.com/lists/oss-security/2021/10/25/6, http://seclists.org/fulldisclosure/2021/Oct/44, https://github.com/signalwire/freeswitch/releases/tag/v1.10.7, http://packetstormsecurity.com/files/164628/FreeSWITCH-1.10.6-Missing-SIP-MESSAGE-Authentication.html, https://github.com/signalwire/freeswitch/security/advisories/GHSA-mjcm-q9h8-9xv3
# Processing CVE ID: CVE-2021-37731
# Fetched data for CVE_ID CVE-2021-37316: CVSS Scores ['7.5'], EPSS 0.15%, Problem Type CWE-89 Improper Neutralization of Special Elements used in an SQL Command ('SQL Injection'),References https://robertchen.cc/blog/2021/03/31/asus-rce
# Processing CVE ID: CVE-2021-37189
# Fetched data for CVE_ID CVE-2021-37317: CVSS Scores ['9.1'], EPSS 0.24%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://robertchen.cc/blog/2021/03/31/asus-rce
# Processing CVE ID: CVE-2021-37188Fetched data for CVE_ID CVE-2021-37315: CVSS Scores ['9.1'], EPSS 0.24%, Problem Type None,References https://robertchen.cc/blog/2021/03/31/asus-rce
#
# Processing CVE ID: CVE-2021-37721Fetched data for CVE_ID CVE-2021-37731: CVSS Scores ['7.2', '6.2'], EPSS 0.06%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
#
# Processing CVE ID: CVE-2021-37344
# Fetched data for CVE_ID CVE-2021-37189: CVSS Scores ['5.0', '7.5'], EPSS 0.15%, Problem Type CWE-311 Missing Encryption of Sensitive Data,References https://www.digi.com/search/results?q=transport, https://raw.githubusercontent.com/reidmefirst/vuln-disclosure/main/2021-04.txt
# Processing CVE ID: CVE-2021-24075
# Fetched data for CVE_ID CVE-2021-37721: CVSS Scores ['9.0', '7.2'], EPSS 0.67%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://cert-portal.siemens.com/productcert/pdf/ssa-280624.pdf, https://www.arubanetworks.com/assets/alert/ARUBA-PSA-2021-016.txt
# Processing CVE ID: CVE-2021-24731
# Fetched data for CVE_ID CVE-2021-37188: CVSS Scores ['6.5', '8.8'], EPSS 0.12%, Problem Type CWE-345 Insufficient Verification of Data Authenticity,References https://www.digi.com/search/results?q=transport, https://raw.githubusercontent.com/reidmefirst/vuln-disclosure/main/2021-04.txt
# Processing CVE ID: CVE-2021-24512Fetched data for CVE_ID CVE-2021-24075: CVSS Scores ['3.5', '6.8', '6.8'], EPSS 0.24%, Problem Type None,References https://portal.msrc.microsoft.com/en-US/security-guidance/advisory/CVE-2021-24075
#
# Processing CVE ID: CVE-2021-24647
# Fetched data for CVE_ID CVE-2021-37344: CVSS Scores ['7.5', '9.8'], EPSS 73.96%, Problem Type CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References https://www.nagios.com/downloads/nagios-xi/change-log/
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-24566
# Fetched data for CVE_ID CVE-2021-24731: CVSS Scores ['7.5', '9.8'], EPSS 28.90%, Problem Type CWE-89 Improper Neutralization of Special Elements used in an SQL Command ('SQL Injection'),References https://wpscan.com/vulnerability/6bed00e4-b363-43b8-a392-d068d342151a
# Processing CVE ID: CVE-2021-24938
# Fetched data for CVE_ID CVE-2021-24566: CVSS Scores ['8.8'], EPSS 0.09%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://jetpack.com/2021/07/22/severe-vulnerability-patched-in-woocommerce-currency-switcher/, https://wpscan.com/vulnerability/a0bc4b13-53fe-462d-8306-8915196d3a5a/
# Processing CVE ID: CVE-2021-24076
# Fetched data for CVE_ID CVE-2021-24647: CVSS Scores ['6.8', '8.1'], EPSS 22.91%, Problem Type CWE-287 Improper Authentication,References https://wpscan.com/vulnerability/40d347b1-b86e-477d-b4c6-da105935ce37
# Processing CVE ID: CVE-2021-24752
# Fetched data for CVE_ID CVE-2021-24512: CVSS Scores ['3.5', '5.4'], EPSS 0.05%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://wpscan.com/vulnerability/458a576e-a7ed-4758-a80c-cd08c370aaf4
# Processing CVE ID: CVE-2021-24091
# Fetched data for CVE_ID CVE-2021-24938: CVSS Scores ['4.3', '6.1'], EPSS 0.13%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://wpscan.com/vulnerability/df8a6f2c-e075-45d5-9262-b4eb63c9351e
# Processing CVE ID: CVE-2021-24679
# Fetched data for CVE_ID CVE-2021-24076: CVSS Scores ['2.1', '5.5', '5.5'], EPSS 0.06%, Problem Type None,References https://portal.msrc.microsoft.com/en-US/security-guidance/advisory/CVE-2021-24076
# Processing CVE ID: CVE-2021-24195
# Fetched data for CVE_ID CVE-2021-24091: CVSS Scores ['6.8', '8.8', '7.8'], EPSS 5.63%, Problem Type CWE-787 Out-of-bounds Write,References https://portal.msrc.microsoft.com/en-US/security-guidance/advisory/CVE-2021-24091, http://packetstormsecurity.com/files/161713/Microsoft-Windows-WindowsCodecsRaw-COlympusE300LoadRaw-Out-Of-Bounds-Write.html
# Processing CVE ID: CVE-2021-28485
# Fetched data for CVE_ID CVE-2021-24679: CVSS Scores ['4.3', '6.1'], EPSS 0.08%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://wpscan.com/vulnerability/7c6c0aac-1733-4abc-8e95-05416636a127
# Attempt 1 for CVE-2021-24752 failed: HTTPSConnectionPool(host='www.cvedetails.com', port=443): Read timed out. (read timeout=10)
# Processing CVE ID: CVE-2021-28110
# Fetched data for CVE_ID CVE-2021-28485: CVSS Scores ['6.5', '4.3'], EPSS 0.06%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://www.ericsson.com/en/about-us/security/psirt, https://www.gruppotim.it/it/footer/red-team.html
# Processing CVE ID: CVE-2021-28216
# Fetched data for CVE_ID CVE-2021-28110: CVSS Scores ['5.0', '7.5'], EPSS 0.09%, Problem Type CWE-611 Improper Restriction of XML External Entity Reference,References https://gist.github.com/kukuxumushi/0b7d90a917ac3480066c4cbf7519b40a
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2021-28801
# Fetched data for CVE_ID CVE-2021-24195: CVSS Scores ['6.5', '8.8'], EPSS 0.14%, Problem Type CWE-285 Improper Authorization,References https://wpscan.com/vulnerability/74889e29-5349-43d1-baf5-1622493be90c
# Processing CVE ID: CVE-2021-28113
# Fetched data for CVE_ID CVE-2021-24752: CVSS Scores ['3.5', '5.7'], EPSS 0.05%, Problem Type CWE-284 Improper Access Control, CWE-352 Cross-Site Request Forgery (CSRF),References https://wpscan.com/vulnerability/181a729e-fffe-457c-9e8d-a4343fd2e630
# Processing CVE ID: CVE-2021-28697
# Fetched data for CVE_ID CVE-2021-28216: CVSS Scores ['4.6', '7.8'], EPSS 0.05%, Problem Type CWE-587 Assignment of a Fixed Address to a Pointer, CWE-763 Release of Invalid Pointer or Reference,References https://bugzilla.tianocore.org/show_bug.cgi?id=2957
# Processing CVE ID: CVE-2021-28703
# Fetched data for CVE_ID CVE-2021-28801: CVSS Scores ['5.0', '7.5', '3.1'], EPSS 0.16%, Problem Type CWE-125 Out-of-bounds Read,References https://www.qnap.com/zh-tw/security-advisory/qsa-21-23
# Processing CVE ID: CVE-2021-28813
# Fetched data for CVE_ID CVE-2021-28113: CVSS Scores ['8.7', '6.7', '6.7'], EPSS 7.28%, Problem Type CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References http://packetstormsecurity.com/files/163428/Okta-Access-Gateway-2020.5.5-Authenticated-Remote-Root.html, https://www.okta.com/security-advisories/cve-2021-28113
# Processing CVE ID: CVE-2021-28805
# ...
# Processing CVE ID: CVE-2018-0311
# Fetched data for CVE_ID CVE-2018-0155: CVSS Scores ['7.8', '8.6'], EPSS 0.86%, Problem Type CWE-388, CWE-755 Improper Handling of Exceptional Conditions,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180328-bfd, http://www.securityfocus.com/bid/103565, https://ics-cert.us-cert.gov/advisories/ICSA-18-107-05, http://www.securitytracker.com/id/1040587
# Processing CVE ID: CVE-2018-0102
# Fetched data for CVE_ID CVE-2018-0344: CVSS Scores ['6.5', '7.2'], EPSS 0.10%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180718-sd-wan-cmd-inject, http://www.securityfocus.com/bid/104868
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2018-0408
# Fetched data for CVE_ID CVE-2018-0312: CVSS Scores ['7.5', '9.8'], EPSS 2.62%, Problem Type CWE-20 Improper Input Validation, CWE-119 Improper Restriction of Operations within the Bounds of a Memory Buffer,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-fx-os-cli-execution, http://www.securitytracker.com/id/1041169, http://www.securityfocus.com/bid/104515
# Processing CVE ID: CVE-2018-0407
# Fetched data for CVE_ID CVE-2018-0408: CVSS Scores ['3.5', '5.4'], EPSS 0.06%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References http://www.securityfocus.com/bid/104948, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180801-sb-rxss
# Processing CVE ID: CVE-2018-0343
# Fetched data for CVE_ID CVE-2018-0407: CVSS Scores ['3.5', '5.4'], EPSS 0.06%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180801-sb-pxss, http://www.securityfocus.com/bid/104947
# Processing CVE ID: CVE-2018-0227
# Processing CVE ID: CVE-2018-0050
# Fetched data for CVE_ID CVE-2018-0102: CVSS Scores ['6.1', '7.4'], EPSS 0.10%, Problem Type CWE-399, CWE-415 Double Free,References http://www.securitytracker.com/id/1040219, http://www.securityfocus.com/bid/102728, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180117-nx-os
# Fetched data for CVE_ID CVE-2018-0311: CVSS Scores ['7.8', '7.5'], EPSS 0.07%, Problem Type CWE-119 Improper Restriction of Operations within the Bounds of a Memory Buffer, CWE-399,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-nx-os-fabric-services-dos, http://www.securitytracker.com/id/1041169
# Processing CVE ID: CVE-2018-0177
# Fetched data for CVE_ID CVE-2018-0050: CVSS Scores ['4.3', '5.9', '7.5'], EPSS 0.30%, Problem Type CWE-20 Improper Input Validation,References http://www.securityfocus.com/bid/106206, http://www.securitytracker.com/id/1041851, https://kb.juniper.net/JSA10884
# Processing CVE ID: CVE-2018-0404
# Fetched data for CVE_ID CVE-2018-0227: CVSS Scores ['5.0', '7.5'], EPSS 0.13%, Problem Type CWE-295 Improper Certificate Validation,References http://www.securitytracker.com/id/1040723, https://ics-cert.us-cert.gov/advisories/ICSA-18-184-01, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180418-asa1, http://www.securityfocus.com/bid/104018
# Processing CVE ID: CVE-2018-0465
# Fetched data for CVE_ID CVE-2018-0343: CVSS Scores ['6.5', '8.8'], EPSS 0.23%, Problem Type CWE-269 Improper Privilege Management, CWE-284 Improper Access Control,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180718-sd-wan-code-ex, http://www.securityfocus.com/bid/104861
# Processing CVE ID: CVE-2018-0395
# Fetched data for CVE_ID CVE-2018-0177: CVSS Scores ['7.8', '7.5'], EPSS 0.30%, Problem Type CWE-19,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180328-ipv4, http://www.securitytracker.com/id/1040588, http://www.securityfocus.com/bid/103563
# Processing CVE ID: CVE-2018-0425
# Fetched data for CVE_ID CVE-2018-0465: CVSS Scores ['4.3', '6.1'], EPSS 0.15%, Problem Type CWE-79 Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20181003-300-switch-xss
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2018-0330Fetched data for CVE_ID CVE-2018-0404: CVSS Scores ['5.0', '7.5'], EPSS 0.24%, Problem Type CWE-89 Improper Neutralization of Special Elements used in an SQL Command ('SQL Injection'),References https://bst.cloudapps.cisco.com/bugsearch/bug/CSCvk27179
#
# Processing CVE ID: CVE-2018-0271
# Fetched data for CVE_ID CVE-2018-0395: CVSS Scores ['2.9', '5.3', '8.8'], EPSS 0.11%, Problem Type CWE-20 Improper Input Validation,References http://www.securityfocus.com/bid/105674, http://www.securitytracker.com/id/1041919, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20181017-fxnx-os-dos
# Processing CVE ID: CVE-2018-0256
# Fetched data for CVE_ID CVE-2018-0425: CVSS Scores ['5.0', '9.8'], EPSS 0.23%, Problem Type CWE-200 Exposure of Sensitive Information to an Unauthorized Actor, CWE-269 Improper Privilege Management,References http://www.securitytracker.com/id/1041676, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180905-rv-routers-disclosure
# Processing CVE ID: CVE-2018-0240
# Fetched data for CVE_ID CVE-2018-0330: CVSS Scores ['6.5', '8.8'], EPSS 0.09%, Problem Type CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'), CWE-264,References http://www.securitytracker.com/id/1041169, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-nxos-nxapi
# Processing CVE ID: CVE-2018-0349
# Fetched data for CVE_ID CVE-2018-0271: CVSS Scores ['7.5', '9.8'], EPSS 0.36%, Problem Type CWE-287 Improper Authentication,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180516-dna2, http://www.securityfocus.com/bid/104191
# Processing CVE ID: CVE-2018-0405
# Fetched data for CVE_ID CVE-2018-0256: CVSS Scores ['5.0', '5.8'], EPSS 0.09%, Problem Type CWE-20 Improper Input Validation,References http://www.securityfocus.com/bid/103951, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180418-pdng
# Processing CVE ID: CVE-2018-0309
# Fetched data for CVE_ID CVE-2018-0240: CVSS Scores ['7.8', '8.6'], EPSS 0.37%, Problem Type CWE-399,References http://www.securitytracker.com/id/1040722, http://www.securityfocus.com/bid/103934, https://ics-cert.us-cert.gov/advisories/ICSA-18-184-01, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180418-asa_inspect
# Processing CVE ID: CVE-2018-0351
# Fetched data for CVE_ID CVE-2018-0349: CVSS Scores ['10.0', '9.8'], EPSS 0.26%, Problem Type CWE-20 Improper Input Validation, CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180718-sdwan-fo, http://www.securityfocus.com/bid/104854
# Processing CVE ID: CVE-2018-0305
# Fetched data for CVE_ID CVE-2018-0405: CVSS Scores ['5.0', '7.5'], EPSS 0.30%, Problem Type CWE-22 Improper Limitation of a Pathname to a Restricted Directory ('Path Traversal'),References https://bst.cloudapps.cisco.com/bugsearch/bug/CSCvk28019
# Processing CVE ID: CVE-2018-0347
# Fetched data for CVE_ID CVE-2018-0309: CVSS Scores ['6.8', '7.7'], EPSS 0.08%, Problem Type CWE-400 Uncontrolled Resource Consumption,References http://www.securitytracker.com/id/1041169, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-n3k-n9k-clisnmp
# Processing CVE ID: CVE-2018-0307
# Batch update completed for 10 CVE IDs.
# Fetched data for CVE_ID CVE-2018-0351: CVSS Scores ['7.2', '7.8'], EPSS 0.04%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References http://www.securityfocus.com/bid/104860, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180718-sdwan-coinj
# Processing CVE ID: CVE-2018-0292
# Fetched data for CVE_ID CVE-2018-0347: CVSS Scores ['7.2', '7.8'], EPSS 0.04%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'),References http://www.securityfocus.com/bid/104862, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180718-sdwan-ci
# Processing CVE ID: CVE-2018-0156
# Fetched data for CVE_ID CVE-2018-0305: CVSS Scores ['5.0', '8.6'], EPSS 0.08%, Problem Type CWE-476 NULL Pointer Dereference,References http://www.securitytracker.com/id/1041169, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-fx-os-fabric-dos
# Processing CVE ID: CVE-2018-0054
# Fetched data for CVE_ID CVE-2018-0292: CVSS Scores ['8.3', '8.8'], EPSS 0.10%, Problem Type CWE-119 Improper Restriction of Operations within the Bounds of a Memory Buffer,References http://www.securitytracker.com/id/1041169, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-nxosigmp
# Processing CVE ID: CVE-2018-0372Fetched data for CVE_ID CVE-2018-0307: CVSS Scores ['7.2', '7.8'], EPSS 0.04%, Problem Type CWE-20 Improper Input Validation, CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References http://www.securitytracker.com/id/1041169, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-nx-os-cli-injection
#
# Processing CVE ID: CVE-2018-0310
# Fetched data for CVE_ID CVE-2018-0156: CVSS Scores ['7.8', '7.5'], EPSS 2.12%, Problem Type CWE-20 Improper Input Validation, CWE-399,References http://www.securityfocus.com/bid/103569, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180328-smi, https://ics-cert.us-cert.gov/advisories/ICSA-18-107-04, http://www.securitytracker.com/id/1040596, https://ics-cert.us-cert.gov/advisories/ICSA-18-107-05
# Processing CVE ID: CVE-2018-0475
# Fetched data for CVE_ID CVE-2018-0372: CVSS Scores ['7.8', '7.5'], EPSS 0.07%, Problem Type CWE-400 Uncontrolled Resource Consumption,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-20180718-nexus-9000-dos, http://www.securitytracker.com/id/1041348
# Processing CVE ID: CVE-2018-0299
# Fetched data for CVE_ID CVE-2018-0475: CVSS Scores ['6.1', '7.4'], EPSS 0.11%, Problem Type CWE-20 Improper Input Validation,References http://www.securityfocus.com/bid/105404, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180926-cmp, http://www.securitytracker.com/id/1041737
# Processing CVE ID: CVE-2018-0663
# Fetched data for CVE_ID CVE-2018-0054: CVSS Scores ['3.3', '6.5', '6.5'], EPSS 0.06%, Problem Type CWE-400 Uncontrolled Resource Consumption,References http://www.securitytracker.com/id/1041855, https://kb.juniper.net/JSA10888
# Processing CVE ID: CVE-2018-0424
# Fetched data for CVE_ID CVE-2018-0299: CVSS Scores ['6.8', '6.5'], EPSS 0.08%, Problem Type CWE-20 Improper Input Validation,References http://www.securitytracker.com/id/1041169, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-n4k-snmp-dos
# Processing CVE ID: CVE-2018-0127
# Batch update completed for 10 CVE IDs.
# Fetched data for CVE_ID CVE-2018-0310: CVSS Scores ['10.0', '9.8'], EPSS 0.33%, Problem Type CWE-125 Out-of-bounds Read, CWE-399,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-nx-os-fabric-dos, http://www.securitytracker.com/id/1041169
# Processing CVE ID: CVE-2018-0255
# Fetched data for CVE_ID CVE-2018-0663: CVSS Scores ['9.0', '8.8'], EPSS 0.14%, Problem Type CWE-798 Use of Hard-coded Credentials,References http://www.iodata.jp/support/information/2018/ts-wrlp/, http://jvn.jp/en/jp/JVN83701666/index.html
# Processing CVE ID: CVE-2018-0301
# Fetched data for CVE_ID CVE-2018-0127: CVSS Scores ['5.0', '9.8'], EPSS 6.10%, Problem Type CWE-200 Exposure of Sensitive Information to an Unauthorized Actor, CWE-306 Missing Authentication for Critical Function,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180207-rv13x_2, http://www.securityfocus.com/bid/102969, http://www.securitytracker.com/id/1040345
# Processing CVE ID: CVE-2018-0306
# Fetched data for CVE_ID CVE-2018-0255: CVSS Scores ['6.8', '8.8'], EPSS 0.10%, Problem Type CWE-352 Cross-Site Request Forgery (CSRF),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180418-iess, http://www.securitytracker.com/id/1040715
# Processing CVE ID: CVE-2018-0092
# Fetched data for CVE_ID CVE-2018-0424: CVSS Scores ['9.0', '8.8'], EPSS 0.08%, Problem Type CWE-77 Improper Neutralization of Special Elements used in a Command ('Command Injection'), CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180905-rv-routers-injection, http://www.securitytracker.com/id/1041677
# Processing CVE ID: CVE-2018-0661
# Fetched data for CVE_ID CVE-2018-0306: CVSS Scores ['7.2', '7.8'], EPSS 0.04%, Problem Type CWE-20 Improper Input Validation, CWE-78 Improper Neutralization of Special Elements used in an OS Command ('OS Command Injection'),References http://www.securitytracker.com/id/1041169, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-nx-os-cli-execution
# Processing CVE ID: CVE-2018-0418
# Fetched data for CVE_ID CVE-2018-0661: CVSS Scores ['8.3', '8.8'], EPSS 0.08%, Problem Type None,References http://www.iodata.jp/support/information/2018/ts-wrlp/, http://jvn.jp/en/jp/JVN83701666/index.html
# Processing CVE ID: CVE-2018-0051
# Fetched data for CVE_ID CVE-2018-0301: CVSS Scores ['10.0', '9.8'], EPSS 0.68%, Problem Type CWE-20 Improper Input Validation, CWE-119 Improper Restriction of Operations within the Bounds of a Memory Buffer,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180620-nxos-bo, http://www.securitytracker.com/id/1041169, http://www.securityfocus.com/bid/104512
# Processing CVE ID: CVE-2018-0019
# Fetched data for CVE_ID CVE-2018-0092: CVSS Scores ['3.6', '7.1'], EPSS 0.04%, Problem Type CWE-264, CWE-862 Missing Authorization,References https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180117-nxos1, http://www.securityfocus.com/bid/102750, http://www.securitytracker.com/id/1040248
# Processing CVE ID: CVE-2018-0665
# Fetched data for CVE_ID CVE-2018-0418: CVSS Scores ['7.8', '8.6'], EPSS 0.30%, Problem Type CWE-20 Improper Input Validation, CWE-400 Uncontrolled Resource Consumption,References http://www.securitytracker.com/id/1041538, http://www.securityfocus.com/bid/105185, https://tools.cisco.com/security/center/content/CiscoSecurityAdvisory/cisco-sa-20180815-asr-ptp-dos
# Batch update completed for 10 CVE IDs.
# Processing CVE ID: CVE-2018-0101Fetched data for CVE_ID CVE-2018-0665: CVSS Scores ['5.2', '6.8'], EPSS 0.06%, Problem Type None,References https://jvn.jp/en/jp/JVN69967692/index.html, https://web116.jp/ced/support/news/contents/2018/20180829b.html, https://flets-w.com/solution/kiki_info/info/180829.html, http://www.rtpro.yamaha.co.jp/RT/FAQ/Security/JVN69967692.html
#
# Processing CVE ID: CVE-2018-0293
# Fetched data for CVE_ID CVE-2018-0019: CVSS Scores ['4.3', '5.9', '5.3'], EPSS 0.10%, Problem Type CWE-20 Improper Input Validation,References http://www.securitytracker.com/id/1040787, https://kb.juniper.net/JSA10847

# %%
import pandas as pd
data = pd.read_csv('filtered_cve_data.csv')
data
# Out:
#               CVE_ID                                        Description  \
# 0      CVE-2009-3564  puppetmasterd in puppet 0.24.6 does not reset ...
# 1      CVE-2009-3341  Buffer overflow on the Linksys WRT54GL wireles...
# 2      CVE-2009-3962  The management interface on the 2wire Gateway ...
# 3      CVE-2009-3828  The web interface for Everfocus EDR1600 DVR al...
# 4      CVE-2009-3322  The Siemens Gigaset SE361 WLAN router allows r...
# ...              ...                                                ...
# 7398  CVE-2024-23910  Cross-site request forgery (CSRF) vulnerabilit...
# 7399  CVE-2024-23727  The YI Smart Kami Vision com.kamivision.yismar...
# 7400  CVE-2024-23842  Improper Input Validation in Hitron Systems DV...
# 7401  CVE-2024-23614  A buffer overflow vulnerability exists in Syma...
# 7402  CVE-2024-23326  Envoy is a cloud-native, open source edge and ...
#
#       Device            Product              Vendor  \
# 0     Switch                NaN                 NaN
# 1     Router                NaN                 NaN
# 2     Router                NaN                 NaN
# 3        NVR                NaN                 NaN
# 4     Router                NaN                 NaN
# ...      ...                ...                 ...
# 7398  Router      WRC-1167GS2-B     ELECOM CO.,LTD.
# 7399  Camera                NaN                 NaN
# 7400     NVR      DVR LGUVR-16H  Hitron Systems DVR
# 7401  Router  Messaging Gateway            Symantec
# 7402  Switch              envoy          envoyproxy
#
#                                                 Version   Firmware  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 7398                                  v1.67 and earlier        NaN
# 7399                                                NaN        NaN
# 7400                                               1.02        NaN
# 7401                                                  0  ['Linux']
# 7402  >= 1.13.0, <= 1.30.1, >= 1.29.0, <= 1.29.4, >=...        NaN
#
#      Patch Availability             Reserved Date            Published Date  \
# 0                   NaN       2009-10-05T00:00:00       2009-10-06T17:22:00
# 1                   NaN      2009-09-24T00:00:00Z      2009-09-24T16:00:00Z
# 2                   NaN       2009-11-17T00:00:00       2009-11-17T18:00:00
# 3                   NaN       2009-10-30T00:00:00       2009-10-30T19:00:00
# 4                   NaN       2009-09-23T00:00:00       2009-09-23T10:00:00
# ...                 ...                       ...                       ...
# 7398                NaN  2024-02-15T01:25:06.163Z  2024-02-28T23:07:02.324Z
# 7399                NaN       2024-01-21T00:00:00       2024-03-28T00:00:00
# 7400                NaN  2024-01-23T04:53:48.120Z  2024-01-23T04:56:41.242Z
# 7401                NaN  2024-01-18T21:37:15.392Z  2024-01-25T23:32:21.154Z
# 7402                NaN  2024-01-15T15:19:19.441Z  2024-06-04T20:05:48.230Z
#
#                    Update Date  \
# 0     2024-08-07T06:31:10.575Z
# 1     2024-09-17T03:03:10.465Z
# 2     2024-08-07T06:45:50.747Z
# 3     2024-08-07T06:38:30.497Z
# 4     2024-08-07T06:22:24.435Z
# ...                        ...
# 7398  2024-09-09T06:36:00.982Z
# 7399  2024-08-27T19:12:26.981Z
# 7400  2024-10-22T03:55:45.527Z
# 7401  2024-09-05T18:28:07.954Z
# 7402  2024-08-01T22:59:32.189Z
#
#                                            Problem Type EPSS_Score  \
# 0                                               CWE-264      0.04%
# 1     CWE-119 Improper Restriction of Operations wit...      3.66%
# 2                      CWE-20 Improper Input Validation      1.75%
# 3                       CWE-287 Improper Authentication      1.86%
# 4                                                   NaN     13.58%
# ...                                                 ...        ...
# 7398                                                NaN      0.04%
# 7399  CWE-94 Improper Control of Generation of Code ...      0.04%
# 7400  CWE-20 Improper Input Validation, CWE-798 Use ...      0.05%
# 7401  CWE-119 Improper Restriction of Operations wit...      0.21%
# 7402  CWE-391 Unchecked Error Condition, CWE-444 Inc...      0.09%
#
#           CVSS_Score                  Severity  \
# 0                4.7                    MEDIUM
# 1               10.0                      HIGH
# 2                7.8                      HIGH
# 3                5.0                    MEDIUM
# 4                7.8                      HIGH
# ...              ...                       ...
# 7398             8.8                      HIGH
# 7399             8.4                      HIGH
# 7400        7.5, 7.4                HIGH, HIGH
# 7401  9.4, 10.0, 9.8  HIGH, CRITICAL, CRITICAL
# 7402   5.9, 8.2, 5.9      MEDIUM, HIGH, MEDIUM
#
#                                                  Vector Exploitability Score  \
# 0                            AV:L/AC:M/Au:N/C:C/I:N/A:N                  3.4
# 1                            AV:N/AC:L/Au:N/C:C/I:C/A:C                 10.0
# 2                            AV:N/AC:L/Au:N/C:N/I:N/A:C                 10.0
# 3                            AV:N/AC:L/Au:N/C:P/I:N/A:N                 10.0
# 4                            AV:N/AC:L/Au:N/C:N/I:N/A:C                 10.0
# ...                                                 ...                  ...
# 7398       CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H                  2.8
# 7399       CVSS:3.1/AV:L/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H                  2.5
# 7400  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:H, ...             3.9, 2.8
# 7401  AV:N/AC:L/Au:N/C:C/I:C/A:N, CVSS:3.1/AV:N/AC:L...       10.0, 3.9, 3.9
# 7402  CVSS:3.1/AV:N/AC:H/PR:N/UI:N/S:U/C:H/I:N/A:N, ...        N/A, 3.9, 2.2
#
#        Impact Score                                    Score Source  \
# 0               6.9                                            NIST
# 1              10.0                                            NIST
# 2               6.9                                            NIST
# 3               2.9                                            NIST
# 4               6.9                                            NIST
# ...             ...                                             ...
# 7398            5.9            134c704f-9b21-4f2e-91b3-4a467353bcc0
# 7399            5.9            134c704f-9b21-4f2e-91b3-4a467353bcc0
# 7400       3.6, 4.0                                 NIST, KrCERT/CC
# 7401  9.2, 5.8, 5.9  Exodus Intelligence, Exodus Intelligence, NIST
# 7402  N/A, 4.2, 3.6                GitHub, Inc., NIST, GitHub, Inc.
#
#                                              references
# 0     https://puppet.com/security/cve/cve-2009-3564,...
# 1     http://www.securitytracker.com/id?1022827, htt...
# 2     http://www.securityfocus.com/archive/1/507587/...
# 3     http://www.securityfocus.com/archive/1/507373/...
# 4     http://www.securityfocus.com/archive/1/506414/...
# ...                                                 ...
# 7398  https://www.elecom.co.jp/news/security/2024022...
# 7399  https://github.com/actuator/yi/blob/main/com.k...
# 7400                  http://www.hitron.co.kr/firmware/
# 7401  https://blog.exodusintel.com/2024/01/25/symant...
# 7402  https://github.com/envoyproxy/envoy/security/a...
#
# [7403 rows x 20 columns]

# %%
data.fillna('No Data Found')
# Out:
#               CVE_ID                                        Description  \
# 0      CVE-2009-3564  puppetmasterd in puppet 0.24.6 does not reset ...
# 1      CVE-2009-3341  Buffer overflow on the Linksys WRT54GL wireles...
# 2      CVE-2009-3962  The management interface on the 2wire Gateway ...
# 3      CVE-2009-3828  The web interface for Everfocus EDR1600 DVR al...
# 4      CVE-2009-3322  The Siemens Gigaset SE361 WLAN router allows r...
# ...              ...                                                ...
# 7398  CVE-2024-23910  Cross-site request forgery (CSRF) vulnerabilit...
# 7399  CVE-2024-23727  The YI Smart Kami Vision com.kamivision.yismar...
# 7400  CVE-2024-23842  Improper Input Validation in Hitron Systems DV...
# 7401  CVE-2024-23614  A buffer overflow vulnerability exists in Syma...
# 7402  CVE-2024-23326  Envoy is a cloud-native, open source edge and ...
#
#       Device            Product              Vendor  \
# 0     Switch      No Data Found       No Data Found
# 1     Router      No Data Found       No Data Found
# 2     Router      No Data Found       No Data Found
# 3        NVR      No Data Found       No Data Found
# 4     Router      No Data Found       No Data Found
# ...      ...                ...                 ...
# 7398  Router      WRC-1167GS2-B     ELECOM CO.,LTD.
# 7399  Camera      No Data Found       No Data Found
# 7400     NVR      DVR LGUVR-16H  Hitron Systems DVR
# 7401  Router  Messaging Gateway            Symantec
# 7402  Switch              envoy          envoyproxy
#
#                                                 Version       Firmware  \
# 0                                         No Data Found  No Data Found
# 1                                         No Data Found  No Data Found
# 2                                         No Data Found  No Data Found
# 3                                         No Data Found  No Data Found
# 4                                         No Data Found  No Data Found
# ...                                                 ...            ...
# 7398                                  v1.67 and earlier  No Data Found
# 7399                                      No Data Found  No Data Found
# 7400                                               1.02  No Data Found
# 7401                                                  0      ['Linux']
# 7402  >= 1.13.0, <= 1.30.1, >= 1.29.0, <= 1.29.4, >=...  No Data Found
#
#      Patch Availability             Reserved Date            Published Date  \
# 0         No Data Found       2009-10-05T00:00:00       2009-10-06T17:22:00
# 1         No Data Found      2009-09-24T00:00:00Z      2009-09-24T16:00:00Z
# 2         No Data Found       2009-11-17T00:00:00       2009-11-17T18:00:00
# 3         No Data Found       2009-10-30T00:00:00       2009-10-30T19:00:00
# 4         No Data Found       2009-09-23T00:00:00       2009-09-23T10:00:00
# ...                 ...                       ...                       ...
# 7398      No Data Found  2024-02-15T01:25:06.163Z  2024-02-28T23:07:02.324Z
# 7399      No Data Found       2024-01-21T00:00:00       2024-03-28T00:00:00
# 7400      No Data Found  2024-01-23T04:53:48.120Z  2024-01-23T04:56:41.242Z
# 7401      No Data Found  2024-01-18T21:37:15.392Z  2024-01-25T23:32:21.154Z
# 7402      No Data Found  2024-01-15T15:19:19.441Z  2024-06-04T20:05:48.230Z
#
#                    Update Date  \
# 0     2024-08-07T06:31:10.575Z
# 1     2024-09-17T03:03:10.465Z
# 2     2024-08-07T06:45:50.747Z
# 3     2024-08-07T06:38:30.497Z
# 4     2024-08-07T06:22:24.435Z
# ...                        ...
# 7398  2024-09-09T06:36:00.982Z
# 7399  2024-08-27T19:12:26.981Z
# 7400  2024-10-22T03:55:45.527Z
# 7401  2024-09-05T18:28:07.954Z
# 7402  2024-08-01T22:59:32.189Z
#
#                                            Problem Type EPSS_Score  \
# 0                                               CWE-264      0.04%
# 1     CWE-119 Improper Restriction of Operations wit...      3.66%
# 2                      CWE-20 Improper Input Validation      1.75%
# 3                       CWE-287 Improper Authentication      1.86%
# 4                                         No Data Found     13.58%
# ...                                                 ...        ...
# 7398                                      No Data Found      0.04%
# 7399  CWE-94 Improper Control of Generation of Code ...      0.04%
# 7400  CWE-20 Improper Input Validation, CWE-798 Use ...      0.05%
# 7401  CWE-119 Improper Restriction of Operations wit...      0.21%
# 7402  CWE-391 Unchecked Error Condition, CWE-444 Inc...      0.09%
#
#           CVSS_Score                  Severity  \
# 0                4.7                    MEDIUM
# 1               10.0                      HIGH
# 2                7.8                      HIGH
# 3                5.0                    MEDIUM
# 4                7.8                      HIGH
# ...              ...                       ...
# 7398             8.8                      HIGH
# 7399             8.4                      HIGH
# 7400        7.5, 7.4                HIGH, HIGH
# 7401  9.4, 10.0, 9.8  HIGH, CRITICAL, CRITICAL
# 7402   5.9, 8.2, 5.9      MEDIUM, HIGH, MEDIUM
#
#                                                  Vector Exploitability Score  \
# 0                            AV:L/AC:M/Au:N/C:C/I:N/A:N                  3.4
# 1                            AV:N/AC:L/Au:N/C:C/I:C/A:C                 10.0
# 2                            AV:N/AC:L/Au:N/C:N/I:N/A:C                 10.0
# 3                            AV:N/AC:L/Au:N/C:P/I:N/A:N                 10.0
# 4                            AV:N/AC:L/Au:N/C:N/I:N/A:C                 10.0
# ...                                                 ...                  ...
# 7398       CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H                  2.8
# 7399       CVSS:3.1/AV:L/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H                  2.5
# 7400  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:H, ...             3.9, 2.8
# 7401  AV:N/AC:L/Au:N/C:C/I:C/A:N, CVSS:3.1/AV:N/AC:L...       10.0, 3.9, 3.9
# 7402  CVSS:3.1/AV:N/AC:H/PR:N/UI:N/S:U/C:H/I:N/A:N, ...        N/A, 3.9, 2.2
#
#        Impact Score                                    Score Source  \
# 0               6.9                                            NIST
# 1              10.0                                            NIST
# 2               6.9                                            NIST
# 3               2.9                                            NIST
# 4               6.9                                            NIST
# ...             ...                                             ...
# 7398            5.9            134c704f-9b21-4f2e-91b3-4a467353bcc0
# 7399            5.9            134c704f-9b21-4f2e-91b3-4a467353bcc0
# 7400       3.6, 4.0                                 NIST, KrCERT/CC
# 7401  9.2, 5.8, 5.9  Exodus Intelligence, Exodus Intelligence, NIST
# 7402  N/A, 4.2, 3.6                GitHub, Inc., NIST, GitHub, Inc.
#
#                                              references
# 0     https://puppet.com/security/cve/cve-2009-3564,...
# 1     http://www.securitytracker.com/id?1022827, htt...
# 2     http://www.securityfocus.com/archive/1/507587/...
# 3     http://www.securityfocus.com/archive/1/507373/...
# 4     http://www.securityfocus.com/archive/1/506414/...
# ...                                                 ...
# 7398  https://www.elecom.co.jp/news/security/2024022...
# 7399  https://github.com/actuator/yi/blob/main/com.k...
# 7400                  http://www.hitron.co.kr/firmware/
# 7401  https://blog.exodusintel.com/2024/01/25/symant...
# 7402  https://github.com/envoyproxy/envoy/security/a...
#
# [7403 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7403 entries, 0 to 7402
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CVE_ID                7403 non-null   object
#  1   Description           7403 non-null   object
#  2   Device                7403 non-null   object
#  3   Product               3838 non-null   object
#  4   Vendor                3311 non-null   object
#  5   Version               3342 non-null   object
#  6   Firmware              141 non-null    object
#  7   Patch Availability    8 non-null      object
#  8   Reserved Date         7384 non-null   object
#  9   Published Date        7384 non-null   object
#  10  Update Date           7403 non-null   object
#  11  Problem Type          6121 non-null   object
#  12  EPSS_Score            7381 non-null   object
#  13  CVSS_Score            7293 non-null   object
#  14  Severity              7295 non-null   object
#  15  Vector                7295 non-null   object
#  16  Exploitability Score  7264 non-null   object
#  17  Impact Score          7262 non-null   object
#  18  Score Source          7295 non-null   object
#  19  references            7399 non-null   object
# dtypes: object(20)
# memory usage: 1.1+ MB
